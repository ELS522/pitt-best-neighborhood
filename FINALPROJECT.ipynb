# %% [markdown]
# # The Best Neighbourhood in Pittsburgh
# The goal of this project is to determine which Pittsburgh neighborhood can be considered as the **best**.

# %% [markdown]
# # Metric
# Our team chose **Safety** as our metric for defining "bestness."
